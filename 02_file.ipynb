# %%
import streamlit as st
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv('synthetic_myntra_dataset.csv')

# %%
df.head()
# Out:
#    id                                    name  \
# 0   1              Men Solid Oversized Cotton
# 1   2          Men Cotton Pure Cotton T-shirt
# 2   3               Women Pure Cotton T-shirt
# 3   4                Typography Print T-shirt
# 4   5  Printed Round Neck Pure Cotton T-shirt
#
#                                                  img asin  price     mrp  \
# 0  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  532.0  1299.0
# 1  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  274.0   499.0
# 2  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  551.0  1199.0
# 3  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  296.0  1099.0
# 4  https://assets.myntassets.com/f_webp,dpr_1.0,q...    -  494.0   899.0
#
#    rating  ratingTotal  discount                 seller  \
# 0     4.1           25        59  Difference of Opinion
# 1     4.2           18        45               Roadster
# 2     4.5           56        54              DILLINGER
# 3     4.0           80        73                Huetrap
# 4     4.2            3        45               Roadster
#
#                                                 purl  sales  \
# 0  https://www.myntra.com/tshirts/difference-of-o...    166
# 1  https://www.myntra.com/tshirts/roadster/roadst...    174
# 2  https://www.myntra.com/tshirts/dillinger/dilli...    157
# 3  https://www.myntra.com/tshirts/huetrap/huetrap...    180
# 4  https://www.myntra.com/tshirts/roadster/roadst...    179
#
#                                              reviews  popularity_score
# 0  The product is just okay, nothing special. Gre...                 1
# 1  Decent quality, could be better. Would buy aga...                 1
# 2  The product is just okay, nothing special. Lov...                 1
# 3  Not satisfied with the product. Product arrive...                 1
# 4  The product is just okay, nothing special. Gre...                 1

# %%
df = df.drop('asin',axis=1)

# %%
df.head()
# Out:
#    id                                    name  \
# 0   1              Men Solid Oversized Cotton
# 1   2          Men Cotton Pure Cotton T-shirt
# 2   3               Women Pure Cotton T-shirt
# 3   4                Typography Print T-shirt
# 4   5  Printed Round Neck Pure Cotton T-shirt
#
#                                                  img  price     mrp  rating  \
# 0  https://assets.myntassets.com/f_webp,dpr_1.0,q...  532.0  1299.0     4.1
# 1  https://assets.myntassets.com/f_webp,dpr_1.0,q...  274.0   499.0     4.2
# 2  https://assets.myntassets.com/f_webp,dpr_1.0,q...  551.0  1199.0     4.5
# 3  https://assets.myntassets.com/f_webp,dpr_1.0,q...  296.0  1099.0     4.0
# 4  https://assets.myntassets.com/f_webp,dpr_1.0,q...  494.0   899.0     4.2
#
#    ratingTotal  discount                 seller  \
# 0           25        59  Difference of Opinion
# 1           18        45               Roadster
# 2           56        54              DILLINGER
# 3           80        73                Huetrap
# 4            3        45               Roadster
#
#                                                 purl  sales  \
# 0  https://www.myntra.com/tshirts/difference-of-o...    166
# 1  https://www.myntra.com/tshirts/roadster/roadst...    174
# 2  https://www.myntra.com/tshirts/dillinger/dilli...    157
# 3  https://www.myntra.com/tshirts/huetrap/huetrap...    180
# 4  https://www.myntra.com/tshirts/roadster/roadst...    179
#
#                                              reviews  popularity_score
# 0  The product is just okay, nothing special. Gre...                 1
# 1  Decent quality, could be better. Would buy aga...                 1
# 2  The product is just okay, nothing special. Lov...                 1
# 3  Not satisfied with the product. Product arrive...                 1
# 4  The product is just okay, nothing special. Gre...                 1

# %%
# ARIMA Sales Forecasting
sales_data = df['sales']
model = ARIMA(sales_data, order=(5, 1, 0))
model_fit = model.fit()
forecast = model_fit.forecast(steps=30)

# %%
# Define trend-related keywords
trend_keywords = [
    "stylish", "fashion", "trendy", "modern", "elegant", "chic", "popular", 
    "comfortable", "durable", "affordable", "quality", "classic", "unique", 
    "beautiful", "cool", "awesome", "great", "nice", "good", "excellent"
]

# Function to extract trends from reviews
def extract_trends(reviews):
    trends = []
    if pd.isnull(reviews) or not reviews:
        return ["general"]  # Assign a default keyword if no review or keywords found
    reviews_lower = reviews.lower()
    for keyword in trend_keywords:
        if keyword in reviews_lower:
            trends.append(keyword)
    if not trends:
        trends.append("general")  # Assign a default keyword if no keywords are found
    return trends

# %%
df['trends'] = df['reviews'].apply(extract_trends)

# %%
df['trends']
# Out:
# 0        [stylish, quality, great, excellent]
# 1        [stylish, quality, great, excellent]
# 2        [stylish, quality, great, excellent]
# 3        [stylish, quality, great, excellent]
# 4                                     [great]
#                          ...
# 49995    [stylish, quality, great, excellent]
# 49996    [stylish, quality, great, excellent]
# 49997    [stylish, quality, great, excellent]
# 49998    [stylish, quality, great, excellent]
# 49999    [stylish, quality, great, excellent]
# Name: trends, Length: 50000, dtype: object

# %%
import matplotlib.pyplot as plt
plt.plot(df['id'],df['popularity_score'])
plt.show()
# Out:
# C:\Users\Sansk\AppData\Local\Temp\ipykernel_30880\2196187113.py:3: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
